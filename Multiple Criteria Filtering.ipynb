# %% [markdown]
# # Applying multiple filter criter to a pandas DataFrame

# %%
# import pandas library
import pandas as pd

emp = pd.read_csv("Datasets/employees.csv")
emp.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
emp[emp.Salary >= 100000]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# ..         ...     ...         ...             ...     ...      ...
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# ...

# %% [markdown]
# ### 2 conditions
#
# * Salary > 100000
# * Team only Finance

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
# when you wrap conditions in parantheses, you give order
# you do those in brackets first before 'and'
# AND
emp[(emp.Salary > 140000) & (emp.Team == 'Finance')]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 83       Shawn    Male   9/23/2005         2:55 AM  148115    6.539
# 96     Cynthia  Female   3/21/1994         8:34 AM  142321    1.737
# 142  Elizabeth  Female   10/9/2003         5:53 PM  146129    5.687
# 160      Kathy  Female   3/18/2000         7:26 PM  149563   16.991
# 318        Roy    Male    8/6/2006         7:52 AM  148225    1.841
# 485     Ashley  Female   8/15/1997         9:48 PM  142415    1.985
# 526    Barbara  Female   3/22/2004         8:11 AM  144677    8.696
# 644  Katherine  Female   8/13/1996        12:21 AM  149908   18.912
# 765      Alice     NaN   4/23/1995         6:35 AM  148339   11.479
# 861      Jerry    Male   3/26/1989         4:15 AM  140850   18.855
# 890        NaN    Male  11/24/2015         3:11 AM  145329    7.100
#
#     Senior Management     Team
# 83               True  Finance
# 96              False  Finance
# 142             False  Finance
# ...

# %%
# OR
emp[(emp.Salary > 140000) | (emp.Team == 'Finance')]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 36      Rachel  Female   2/16/2009         8:47 PM  142032   12.599
# ..         ...     ...         ...             ...     ...      ...
# 981      James    Male   1/15/1993         5:19 PM  148985   19.280
# 983       John    Male  12/23/1982        10:35 PM  146907   11.738
# 987     Gloria  Female   12/8/2014         5:08 AM  136709   10.331
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# ...

# %%
(emp.Salary > 140000) | (emp.Team == 'Finance')
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
(emp.Salary > 140000) & (emp.Team == 'Finance')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# ### What if you want Team Finance , Business Development and Marketing ?

# %%
emp[(emp.Team == 'Finance') | (emp.Team == 'Business Development') | (emp.Team == 'Marketing')]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# ..         ...     ...         ...             ...     ...      ...
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
# fast method
filter_list = ['Finance', 'Business Development', 'Marketing']
emp[emp.Team.isin(filter_list)]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# ..         ...     ...         ...             ...     ...      ...
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...
